# %%
('hello world')
# Out:
# 'hello world'

# %%
import pandas as pd

# %%
#csv_df= pd.read_csv('fuel_ferc1.csv')

# %%
html_df = pd.read_csv('C:\\Users\\Lama\\Desktop\\fuel_ferc1.csv')

# %%
df= pd.read_csv ('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
df.describe(include='all')
# Out:
#                        record_id  utility_id_ferc1   report_year  \
# count                      29523      29523.000000  29523.000000
# unique                     29523               NaN           NaN
# top     f1_fuel_2018_12_164_0_13               NaN           NaN
# freq                           1               NaN           NaN
# mean                         NaN        118.601836   2005.806050
# std                          NaN         74.178353      7.025483
# min                          NaN          1.000000   1994.000000
# 25%                          NaN         55.000000   2000.000000
# 50%                          NaN        122.000000   2006.000000
# 75%                          NaN        176.000000   2012.000000
# max                          NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
html_df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
html_df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
pwd
# Out:
# 'C:\\Users\\Lama'

# %%
df.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
csv_df= pd.read_csv ('C:\\Users\\Lama\\desktop\\fuel_ferc1.csv')

# %%
csv_df.to_csv ('C:\\Users\\Lama\\desktop\\fuel_ferc1.csv', index=False)

# %%
csv_df.to_csv
# Out:
# <bound method NDFrame.to_csv of                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
url= 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'

# %%
fuel_df= pd.read_csv (url, error_bad_lines=False)

# %%
fuel_df.describe(include='all')
# Out:
#                        record_id  utility_id_ferc1   report_year  \
# count                      29523      29523.000000  29523.000000
# unique                     29523               NaN           NaN
# top     f1_fuel_2018_12_164_0_13               NaN           NaN
# freq                           1               NaN           NaN
# mean                         NaN        118.601836   2005.806050
# std                          NaN         74.178353      7.025483
# min                          NaN          1.000000   1994.000000
# 25%                          NaN         55.000000   2000.000000
# 50%                          NaN        122.000000   2006.000000
# 75%                          NaN        176.000000   2012.000000
# max                          NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
csv_df.describe(include='all')
# Out:
#                        record_id  utility_id_ferc1   report_year  \
# count                      29523      29523.000000  29523.000000
# unique                     29523               NaN           NaN
# top     f1_fuel_2018_12_164_0_13               NaN           NaN
# freq                           1               NaN           NaN
# mean                         NaN        118.601836   2005.806050
# std                          NaN         74.178353      7.025483
# min                          NaN          1.000000   1994.000000
# 25%                          NaN         55.000000   2000.000000
# 50%                          NaN        122.000000   2006.000000
# 75%                          NaN        176.000000   2012.000000
# max                          NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
csv_df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
csv_df.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
csv_df['fuel_unit'] = csv_df ['fuel_unit'].fillna(value='mcf')

# %%
csv_df.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
csv_df.groupby('fuel_unit').first()
# Out:
#                          record_id  utility_id_ferc1  report_year  \
# fuel_unit
# bbl          f1_fuel_1994_12_6_0_2                 6         1994
# gal        f1_fuel_2000_12_20_0_10                20         2000
# gramsU       f1_fuel_1994_12_9_0_8                 9         1994
# kgU          f1_fuel_1994_12_2_1_1                 2         1994
# mcf         f1_fuel_1994_12_2_0_10                 2         1994
# mmbtu       f1_fuel_1994_12_46_1_7                46         1994
# mwdth      f1_fuel_1994_12_17_2_14                17         1994
# mwhth       f1_fuel_1994_12_63_0_2                63         1994
# ton          f1_fuel_1994_12_1_0_7                 1         1994
#
#             plant_name_ferc1 fuel_type_code_pudl  fuel_qty_burned  \
# fuel_unit
# bbl             clinch river                 oil           6510.0
# gal                  hallock                 oil          56925.0
# gramsU            pch bt 2&3             nuclear         204246.0
# ...

# %%
csv_df.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
csv_df1= csv_df.iloc[0:20000].reset_index(drop=True)
csv_df2= csv_df.iloc[20000:].reset_index(drop=True)

# %%
csv_df1= csv_df.iloc[0:20000]
csv_df2= csv_df.iloc[20000:]

# %%
assert len(csv_df) == (len(csv_df1) + len(csv_df2))

# %%
pd.merge (csv_df1, csv_df2, how="outer")
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
csv_df.duplicated().any()
# Out:
# False

# %%
pd.concat([csv_df, fuel_df])
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
csv_df.duplicated().any()
# Out:
# False

# %%
days=np.array(['Monday', 'Tuesday', 'Wednesday'])

# %%
import numpy as np

# %%
days
# Out:
# array(['Monday', 'Tuesdat', 'Wednesday'], dtype='<U9')

# %%
print (days)
# Out:
# ['Monday' 'Tuesdat' 'Wednesday']

# %%
numpy_days= pd.Series(days)

# %%
numpy_days
# Out:
# 0       Monday
# 1      Tuesday
# 2    Wednesday
# dtype: object

# %%
days= pd.Series(['Monday', 'Tuesday', 'wednesday'], index=['a', 'b', 'c'])

# %%
days
# Out:
# a       Monday
# b      Tuesday
# c    wednesday
# dtype: object

# %%
days1= pd.Series({'a':'Monday', 'b':'Tuesday', 'off_day':'Wednesday'})

# %%
print(days1)
# Out:
# a             Monday
# b            Tuesday
# off_day    Wednesday
# dtype: object

# %%
days[2:]
# Out:
# c    wednesday
# dtype: object

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
x= np.array ([[1,2,3], [4,5,6]])

# %%
y=['a', 1,2,'b']
y.append(7)

# %%
z= ['a', 1,2,'b']
z.extend ([8,9])

# %%
print(x)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print (y)
# Out:
# ['a', 1, 2, 'b', 7]

# %%
print (z)
# Out:
# ['a', 1, 2, 'b', 8, 9]

# %%
18000*3
# Out:
# 54000
